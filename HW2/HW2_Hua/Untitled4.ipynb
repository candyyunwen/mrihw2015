# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


y1=1
t = np.arange(0.1,1.1, 0.1)
t2 = np.arange(1,1.1, 0.01)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
print (y1,y2,Mxy)
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(t, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
plt.plot(t2,y3)
print (y1,y2,Mxy)


x = np.arange(1.1,2.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+1
plt.plot(t3,y3)
print (y1,y2,Mxy)


x = np.arange(2.1,3.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+2
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(3.1,4.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+3
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(4.1,5.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+4
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(5.1,6.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+5
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(6.1,7.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+6
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(7.1,8.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+7
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(8.1,9.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+8
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(9.1,10.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+9
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(10.1,11.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+10
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(11.1,12.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+11
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(12.1,13.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+12
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(13.1,14.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+13
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(14.1,15.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+14
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(15.2,16.2, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+15
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(16.1,17.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+16
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(17.1,18.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+17
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(18.1,19.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+18
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(19.1,20.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+19
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(20.1,21.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+20
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(21.1,22.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+21
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(22.1,23.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+22
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(23.1,24.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+23
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(24.1,25.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+24
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(25.1,26.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+25
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(26.1,27.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+26
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(27.1,28.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+27
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(28.1,29.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+28
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(29.1,30.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+29
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(30.1,31.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+30
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(31.1,32.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+31
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(32.1,33.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+32
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(33.1,34.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+33
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(34.1,35.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+34
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(34.1,35.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+35
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(35.1,36.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+36
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(36.1,37.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+37
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(37.1,38.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+38
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(38.1,39.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]
y3=np.cos(25./180*np.pi)*y1*t2
t3=t2+39
plt.plot(t3,y3)
print (y1,y2,Mxy)

x = np.arange(39.1,40.1, 0.1)
y2= np.cos(25./180*np.pi)*y1
Mxy = np.sin(25./180*np.pi)*y1
y1=(y2-1)*np.exp(-0.1*t)+1
plt.plot(x, y1)
y1=y1[9]

print (y1,y2,Mxy)
# Out:
# (1, 0.90630778703664994, 0.42261826174069944)
# (0.91522377993216708, 0.90630778703664994, 0.42261826174069944)
# (0.84570209134413044, 0.82947443863364023, 0.3867902829786849)
# (0.78869005211585819, 0.76646639089836566, 0.35740914779433064)
# (0.74193669092771541, 0.71479593579094358, 0.33331481887738562)
# (0.70359607354273046, 0.67242300047599268, 0.31355599464151768)
# (0.67215442091916211, 0.63767460038018808, 0.29735254956821006)
# (0.646370341602581, 0.60917878577014672, 0.2840647329901827)
# (0.62522581862972038, 0.58581047390395868, 0.27316791020882486)
# (0.60788601579013157, 0.56664702808047973, 0.26423184866469823)
# (0.59366631630096722, 0.55093182974128019, 0.25690373132970479)
# (0.58200529250313648, 0.53804440536492948, 0.25089422664911903)
# (0.57244253935795253, 0.52747592869213578, 0.24596606504156288)
# (0.5646004965578395, 0.51880913105114634, 0.24192467092988981)
# (0.55816954154466147, 0.51170182659512919, 0.2386104804332099)
# ...
